# %%
import pandas as pd 
Sales_Data = pd.read_csv(r'C:\Users\sandy\Desktop\Project_realected_practice\DataSpark Illuminating Insights for Global Electronics\Sales.csv', encoding='iso-8859-1')
Sales_Data.shape
# Out:
# (62884, 9)

# %%
import pandas as pd 
ExchangeRates_Data = pd.read_csv(r'C:\Users\sandy\Desktop\Project_realected_practice\DataSpark Illuminating Insights for Global Electronics\Customers.csv', encoding='iso-8859-1')
ExchangeRates_Data.head()
ExchangeRates_Data.shape
# Out:
# (15266, 10)

# %%
import pandas as pd 
ExchangeRates_Data1 = pd.read_csv(r'C:\Users\sandy\Desktop\Project_realected_practice\DataSpark Illuminating Insights for Global Electronics\Exchange_Rates.csv', encoding='iso-8859-1')
ExchangeRates_Data1.head()
# Out:
#        Date Currency  Exchange
# 0  1/1/2015      USD    1.0000
# 1  1/1/2015      CAD    1.1583
# 2  1/1/2015      AUD    1.2214
# 3  1/1/2015      EUR    0.8237
# 4  1/1/2015      GBP    0.6415

# %%
import pandas as pd

Sales_Data = pd.read_csv(r'C:\Users\sandy\Desktop\Project_realected_practice\DataSpark Illuminating Insights for Global Electronics\Sales.csv', encoding='iso-8859-1')


Customer_Data = pd.read_csv(r'C:\Users\sandy\Desktop\Project_realected_practice\DataSpark Illuminating Insights for Global Electronics\Customers.csv', encoding='iso-8859-1')


# Merging the two tables based on the 'Currency Code' from Sales_Data and 'Currency' from ExchangeRates_Data
merged_data = pd.merge(Sales_Data, Customer_Data , left_on='CustomerKey', right_on='CustomerKey')
Final=pd.DataFrame(merged_data)
Final.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1   1/1/2016           NaN       265598        10
# 1        366001          1   1/1/2016     1/13/2016      1269051         0
# 2        366001          2   1/1/2016     1/13/2016      1269051         0
# 3        366002          1   1/1/2016     1/12/2016       266019         0
# 4        366002          2   1/1/2016     1/12/2016       266019         0
#
#    ProductKey  Quantity Currency Code  Gender            Name      City  \
# 0        1304         1           CAD    Male    Tyler Vaught    London
# 1        1048         2           USD    Male  Frank Upchurch   Auberry
# 2        2007         1           USD    Male  Frank Upchurch   Auberry
# 3        1106         7           CAD  Female      Joan Roche  Red Deer
# 4         373         1           CAD  Female      Joan Roche  Red Deer
#
#   State Code       State Zip Code        Country      Continent    Birthday
# ...

# %%
Sales_Data.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1   1/1/2016           NaN       265598        10
# 1        366001          1   1/1/2016     1/13/2016      1269051         0
# 2        366001          2   1/1/2016     1/13/2016      1269051         0
# 3        366002          1   1/1/2016     1/12/2016       266019         0
# 4        366002          2   1/1/2016     1/12/2016       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
Customer_Data.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia    7/3/1939
# 1  Western Australia     6522  Australia  Australia   9/27/1979
# 2           Victoria     3380  Australia  Australia   5/26/1947
# 3    South Australia     5223  Australia  Australia   9/17/1957
# 4           Victoria     3698  Australia  Australia  11/19/1965

# %%
265598
# Out:
# 265598

# %%
merged_data[merged_data['CustomerKey']==265598]
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1    1/1/2016           NaN       265598
# 9638         891000          1    6/9/2017           NaN       265598
# 9639         891000          2    6/9/2017           NaN       265598
# 9640         891000          3    6/9/2017           NaN       265598
# 9641         891000          4    6/9/2017           NaN       265598
# 44706       1749017          1  10/15/2019    10/23/2019       265598
# 44707       1749017          2  10/15/2019    10/23/2019       265598
# 44708       1749017          3  10/15/2019    10/23/2019       265598
#
#        StoreKey  ProductKey  Quantity Currency Code Gender          Name  \
# 0            10        1304         1           CAD   Male  Tyler Vaught
# 9638          9         385         2           CAD   Male  Tyler Vaught
# 9639          9         174         1           CAD   Male  Tyler Vaught
# ...

# %%
import pandas as pd
Stores_Data = pd.read_csv(r'C:\Users\sandy\Desktop\Project_realected_practice\DataSpark Illuminating Insights for Global Electronics\Stores.csv', encoding='iso-8859-1')
Stores_Data.head()
# Out:
#    StoreKey    Country                         State  Square Meters  Open Date
# 0         1  Australia  Australian Capital Territory          595.0   1/1/2008
# 1         2  Australia            Northern Territory          665.0  1/12/2008
# 2         3  Australia               South Australia         2000.0   1/7/2012
# 3         4  Australia                      Tasmania         2000.0   1/1/2010
# 4         5  Australia                      Victoria         2000.0  12/9/2015

# %%
merged_data_version2 = pd.merge(merged_data, Stores_Data , left_on='StoreKey', right_on='StoreKey')
Final=pd.DataFrame(merged_data_version2)
Final.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1   1/1/2016           NaN       265598        10
# 1        366001          1   1/1/2016     1/13/2016      1269051         0
# 2        366001          2   1/1/2016     1/13/2016      1269051         0
# 3        366002          1   1/1/2016     1/12/2016       266019         0
# 4        366002          2   1/1/2016     1/12/2016       266019         0
#
#    ProductKey  Quantity Currency Code  Gender  ... State Code     State_x  \
# 0        1304         1           CAD    Male  ...         ON     Ontario
# 1        1048         2           USD    Male  ...         CA  California
# 2        2007         1           USD    Male  ...         CA  California
# 3        1106         7           CAD  Female  ...         AB     Alberta
# 4         373         1           CAD  Female  ...         AB     Alberta
#
# ...

# %%
Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
#  9   Gender         62884 non-null  object
#  10  Name           62884 non-null  object
#  11  City           62884 non-null  object
#  12  State Code     62854 non-null  object
#  13  State_x        62884 non-null  object
#  14  Zip Code       62884 non-null  object
#  15  Country_x      62884 non-null  object
#  16  Continent      62884 non-null  object
# ...

# %% [markdown]
# Since the customer and order have a same column name called state and country it was renamed as a state_x and state_y country_x and country_y

# %%
import pandas as pd
Products_Data = pd.read_csv(r'C:\Users\sandy\Desktop\Project_realected_practice\DataSpark Illuminating Insights for Global Electronics\Products.csv', encoding='iso-8859-1')
Products_Data.head()
# Out:
#    \ProductKey                         Product Name    Brand   Color  \
# 0            1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1            2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2            3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3            4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4            5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
Products_Data['Subcategory'].unique()
# Out:
# array(['MP4&MP3', 'Recording Pen', 'Bluetooth Headphones', 'Televisions',
#        'VCD & DVD', 'Home Theater System', 'Car Video', 'Laptops',
#        'Desktops', 'Monitors', 'Projectors & Screens',
#        'Printers, Scanners & Fax', 'Computers Accessories',
#        'Digital Cameras', 'Digital SLR Cameras', 'Camcorders',
#        'Cameras & Camcorders Accessories', 'Home & Office Phones',
#        'Touch Screen Phones', 'Smart phones & PDAs', 'Movie DVD',
#        'Boxed Games', 'Download Games', 'Washers & Dryers',
#        'Refrigerators', 'Microwaves', 'Water Heaters', 'Coffee Machines',
#        'Lamps', 'Air Conditioners', 'Fans', 'Cell phones Accessories'],
#       dtype=object)

# %%
Products_Data.shape
# Out:
# (2517, 10)

# %%
Products_Data.rename(columns = {r'\ProductKey':'ProductKey'}, inplace = True)
Products_Data.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
Products_Data.shape
# Out:
# (2517, 10)

# %%
Products_Data['Category'].unique()
# Out:
# array(['Audio', 'TV and Video', 'Computers', 'Cameras and camcorders',
#        'Cell phones', 'Music, Movies and Audio Books', 'Games and Toys',
#        'Home Appliances'], dtype=object)

# %%
Electronic_Data = pd.merge(merged_data, Stores_Data , left_on='StoreKey', right_on='StoreKey')
Final=pd.DataFrame(Electronic_Data)
Final.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1   1/1/2016           NaN       265598        10
# 1        366001          1   1/1/2016     1/13/2016      1269051         0
# 2        366001          2   1/1/2016     1/13/2016      1269051         0
# 3        366002          1   1/1/2016     1/12/2016       266019         0
# 4        366002          2   1/1/2016     1/12/2016       266019         0
#
#    ProductKey  Quantity Currency Code  Gender  ... State Code     State_x  \
# 0        1304         1           CAD    Male  ...         ON     Ontario
# 1        1048         2           USD    Male  ...         CA  California
# 2        2007         1           USD    Male  ...         CA  California
# 3        1106         7           CAD  Female  ...         AB     Alberta
# 4         373         1           CAD  Female  ...         AB     Alberta
#
# ...

# %%
import pandas as pd 
ExchangeRates_Data = pd.read_csv(r'C:\Users\sandy\Desktop\Project_realected_practice\DataSpark Illuminating Insights for Global Electronics\Exchange_Rates.csv', encoding='iso-8859-1')
ExchangeRates_Data.head()
#ExchangeRates_Data.shape
# Out:
#        Date Currency  Exchange
# 0  1/1/2015      USD    1.0000
# 1  1/1/2015      CAD    1.1583
# 2  1/1/2015      AUD    1.2214
# 3  1/1/2015      EUR    0.8237
# 4  1/1/2015      GBP    0.6415

# %%
ExchangeRates_Data['Currency'].unique()
# Out:
# array(['USD', 'CAD', 'AUD', 'EUR', 'GBP'], dtype=object)

# %%
a=ExchangeRates_Data['Date'].unique()
b=len(a)
b
# Out:
# 2243

# %%
ExchangeRates_Data['Date'].groupby('Currency')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 ExchangeRates_Data['Date'].groupby('Currency')
#
# File c:\Users\sandy\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:2247, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2244     raise TypeError("as_index=False only valid with DataFrame")
#    2245 axis = self._get_axis_number(axis)
# -> 2247 return SeriesGroupBy(
#    2248     obj=self,
#    2249     keys=by,
#    2250     axis=axis,
#    2251     level=level,
#    2252     as_index=as_index,
#    2253     sort=sort,
#    2254     group_keys=group_keys,
#    2255     observed=observed,
#    2256     dropna=dropna,
#    2257 )
#
# ...

# %%
ExchangeRates_Data['Date'].unique().shape
# Out:
# (2243,)

# %%
ExchangeRates_Data['Date']
# Out:
# 0         1/1/2015
# 1         1/1/2015
# 2         1/1/2015
# 3         1/1/2015
# 4         1/1/2015
#            ...
# 11210    2/20/2021
# 11211    2/20/2021
# 11212    2/20/2021
# 11213    2/20/2021
# 11214    2/20/2021
# Name: Date, Length: 11215, dtype: object

# %%
import pandas as pd 
Overview = pd.read_csv(r'C:\Users\sandy\Desktop\Project_realected_practice\DataSpark Illuminating Insights for Global Electronics\Data_Dictionary.csv', encoding='iso-8859-1')
Overview
# Out:
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# ...
